# %%
import os
import os.path
import re
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

# %%
opts = Options()
chromium_path = "/snap/chromium/current/usr/lib/chromium-browser/chrome"
opts.binary_location = chromium_path
opts.add_argument("--headless")
driver = webdriver.Chrome(options=opts)

# %%
driver.get('https://play.cscg.live/rules')
time.sleep(5) # Too lazy to implement a proper check if the site has loaded

# %%
elements = driver.find_elements(By.TAG_NAME, 'CODE')

# %%
for element in elements:
    print(element.text)
# Out:
# CSCG{h3r3_is_a_r3w4rd_f0r_y0ur_tr0ubles}
# CSCG{h3r3_is_a_r3w4rd_f0r_y0ur_tr0ubles}

# %%
driver.quit()
